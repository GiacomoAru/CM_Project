# %%
from math_utils import *
from plot_utils import *
from low_rank_approximation import *

test_dir = './data/second_test'
df_path = './data/second_test.csv'

# %%
compute_global_stats_df(test_dir, df_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 compute_global_stats_df(test_dir, df_path)
#
# File c:\Users\cicci\Desktop\uni\CM\CM_Project\math_utils.py:405, in compute_global_stats_df(test_dir, save_path)
#     402 # Iterate over all directories and subdirectories
#     403 for subfolder in main_folder.rglob('*'):
#     404     # Check if the path is a directory and is at the third level
# --> 405     if subfolder.is_dir() and len(subfolder.relative_to(main_folder).parts) == 3:
#     406         dummy_df = pd.read_csv((subfolder / 'data.csv').absolute())
#     407         with open(subfolder / 'input_values.json', 'r') as f:
#
# File c:\Users\cicci\AppData\Local\Programs\Python\Python312\Lib\pathlib.py:875, in Path.is_dir(self)
#     871 """
#     872 Whether this path is a directory.
#     873 """
#     874 try:
# ...

# %% [markdown]
# # identity

# %%
filter = {'c_name': lambda x: (x == 'g_identity') | (x == 's_identity')}
new_col = {'perturbation': lambda x: x['m_name'].apply(lambda x: int(x.split('_')[-1]))}
plot_agg_global_df(x='iteration', y='k', filter=filter, new_col=new_col, logscale=(True, True), dataframe_path=df_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 filter = {'c_name': lambda x: (x == 'g_identity') | (x == 's_identity')}
#       2 new_col = {'perturbation': lambda x: x['m_name'].apply(lambda x: int(x.split('_')[-1]))}
# ----> 3 plot_agg_global_df(x='iteration', y='k', filter=filter, new_col=new_col, logscale=(True, True), dataframe_path=df_path)
#
# File c:\Users\cicci\Desktop\uni\CM\CM_Project\plot_utils.py:334, in plot_agg_global_df(x, y, filter, new_col, logscale, dataframe_path)
#     332     old_df = old_df[filter[fun](old_df[fun])]
#     333 for c in new_col:
# --> 334     old_df[c] = new_col[c](old_df)
#     336 # Create new columns
#     337 old_df['m_n'] = old_df['m'] * old_df['n']
#
# Cell In[3], line 2, in <lambda>(x)
#       1 filter = {'c_name': lambda x: (x == 'g_identity') | (x == 's_identity')}
# ...

# %% [markdown]
# # low rank

# %%
filter = {'c_name': lambda x: (x == 'g_low_rank') | (x == 's_low_rank')}
new_col = {'rank': lambda x: x['m_name'].apply(lambda x: int(x.split('_')[-1]))}
plot_agg_global_df(x='rank', y='k', filter=filter, new_col=new_col, logscale=(False, False), dataframe_path=df_path)
# Out:
# c_name has only one value:  g_low_rank
# init_method has only one value:  sketching_b
# epsilon has only one value: 1e-15
# pc_name has only one value:  PC_Giacominico
# date has too many categories
# m has only one value: 100.0
# n has only one value: 100.0
# m_n has only one value: 10000.0

# %% [markdown]
# # norm

# %%
filter = {'c_name': lambda x: (x == 'g_norm') | (x == 's_norm')}
new_col = {'norm_mul': lambda x: x['t_name'].apply(lambda x: int(x.split('Vmul')[-1]))}
plot_agg_global_df(x='norm_mul', y='k', filter=filter, new_col=new_col, logscale=(True, False), dataframe_path=df_path)
# Out:
# c_name has only one value:  g_norm
# m_name has only one value:  100x100_normal
# t_name has too many categories
# init_method has only one value:  snormal
# epsilon has only one value: 1e-15
# pc_name has only one value:  PC_Giacominico
# date has too many categories
# m has only one value: 100.0
# n has only one value: 100.0
# m_n has only one value: 10000.0

# %% [markdown]
# # special

# %%
filter = {'c_name': lambda x: (x == 'g_special') | (x == 's_special')}
new_col = {'type': lambda x: x['m_name'].apply(lambda x: x.split('_')[-1])}
plot_agg_global_df(x='iteration', y='k', filter=filter, new_col=new_col, logscale=(True, False), dataframe_path=df_path)
# Out:
# c_name has only one value:  g_special
# m_name has too many categories
# init_method has only one value:  sketching_g
# epsilon has only one value: 1e-08
# pc_name has only one value:  PC_Giacominico
# date has too many categories

# %% [markdown]
# # img

# %%
filter = {'c_name': lambda x: (x == 'g_img') | (x == 's_img')}
new_col = {'type': lambda x: x['m_name'].apply(lambda x: x.split('_')[0])}
plot_agg_global_df(x='iteration', y='k', filter=filter, new_col=new_col, logscale=(True, False), dataframe_path=df_path)
# Out:
# c_name has only one value:  g_img
# m_name has too many categories
# init_method has only one value:  sketching_g
# pc_name has only one value:  PC_Giacominico
# date has too many categories

# %% [markdown]
# # Checking possible errors
# The following are execution that measured only one iteration, they can be error. We will check if they are.
